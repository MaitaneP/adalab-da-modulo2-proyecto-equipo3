# %% [markdown]
# # Proyecto 2

# %%
import pandas as pd
import numpy as np
import pickle

# %%
df_csv = pd.read_csv("datos/exported_db_data.csv")
df_csv.head()
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10  \
# 0        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN
#
#             Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15  \
# ...

# %%
df_csv2 = pd.read_csv("datos/data_remaning_kaggle.csv", index_col= 0)
df_csv2.head()
# Out:
#    index                                         Q18_Part_1  \
# 0      0  General purpose image/video tools (PIL, cv2, s...
# 1      1                                                NaN
# 2      2                                                NaN
# 3      3  General purpose image/video tools (PIL, cv2, s...
# 4      4                                                NaN
#
#                                           Q18_Part_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Image segmentation methods (U-Net, Mask R-CNN,...
# 4                                                NaN
#
#                                           Q18_Part_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Object detection methods (YOLOv3, RetinaNet, etc)
# ...

# %%
import xml.etree.ElementTree as ET

# %%
df_xml = pd.read_xml("datos/data_xml_clean.xml")
df_xml.head()
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man
# 1        1      1   784  50-54    Man
# 2        2      2   924  22-24    Man
# 3        3      3   575  45-49    Man
# 4        4      4   781  45-49    Man

# %%
f = open("datos/data_txt_clean.txt", mode='r', encoding='utf-8')
fichero_txt = f.readlines()
fichero_txt
# Out:
# ['index;Q3;Q4;Q5;Q6;Q8;Q11;Q13;Q15;Q20;Q21;Q22;Q23;Q25;Q26;Q33;Q35;Q41;Q7;Q9;Q12;Q14;Q16;Q17;Q24;Q32;Q34\n',
#  '0;India;Bachelor’s degree;Other;5-10 years;Python;A laptop;2-5 times;5-10 years;Manufacturing/Fabrication;50-249 employees;3-4;No (we do not use ML methods);25,000-29,999;$100-$999;null;null;Local development environments (RStudio, JupyterLab, etc.);Python, R; Vim / Emacs;Google Cloud TPUs ; Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ,Leaflet / Folium ;Scikit-learn , TensorFlow ,Caret ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Dense Neural Networks (MLPs, etc), Convolutional Neural Networks, Recurrent Neural Networks; None of these activities are an important part of my role at work; PostgreSQL ; None\n',
# ...

# %%
fichero_txt_lista = []
for i in fichero_txt:
    i = i.strip('\n')
    i = i.split(';')
    fichero_txt_lista.append(i)

fichero_txt_lista
# Out:
# [['index',
#   'Q3',
#   'Q4',
#   'Q5',
#   'Q6',
#   'Q8',
#   'Q11',
#   'Q13',
#   'Q15',
#   'Q20',
#   'Q21',
#   'Q22',
#   'Q23',
#   'Q25',
#   'Q26',
#   'Q33',
#   'Q35',
#   'Q41',
#   'Q7',
#   'Q9',
#   'Q12',
#   'Q14',
#   'Q16',
#   'Q17',
#   'Q24',
#   'Q32',
#   'Q34'],
#  ['0',
#   'India',
#   'Bachelor’s degree',
#   'Other',
#   '5-10 years',
#   'Python',
#   'A laptop',
#   '2-5 times',
#   '5-10 years',
#   'Manufacturing/Fabrication',
#   '50-249 employees',
#   '3-4',
#   'No (we do not use ML methods)',
#   '25,000-29,999',
#   '$100-$999',
#   'null',
#   'null',
#   'Local development environments (RStudio, JupyterLab, etc.)',
#   'Python, R',
#   ' Vim / Emacs',
#   'Google Cloud TPUs ',
#   ' Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ,Leaflet / Folium ',
#   'Scikit-learn , TensorFlow ,Caret ',
# ...

# %%
df_txt = pd.DataFrame(fichero_txt_lista,columns= fichero_txt_lista[0])
df_txt.head()
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0  index         Q3                 Q4                       Q5          Q6
# 1      0      India  Bachelor’s degree                    Other  5-10 years
# 2      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 3      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 4      3     Mexico    Doctoral degree       Research Scientist   20+ years
#
#        Q8                                                Q11  \
# 0      Q8                                                Q11
# 1  Python                                           A laptop
# 2  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 3  Python                                           A laptop
# 4  Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                   Q13                                    Q15  \
# 0                 Q13                                    Q15
# ...

# %%
df_txt.set_index(['index'], inplace= True)
df_txt.head()
# Out:
#               Q3                 Q4                       Q5          Q6  \
# index
# index         Q3                 Q4                       Q5          Q6
# 0          India  Bachelor’s degree                    Other  5-10 years
# 1      Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2       Pakistan    Master’s degree        Software Engineer   1-3 years
# 3         Mexico    Doctoral degree       Research Scientist   20+ years
#
#            Q8                                                Q11  \
# index
# index      Q8                                                Q11
# 0      Python                                           A laptop
# 1      Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2      Python                                           A laptop
# 3      Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                       Q13                                    Q15  \
# index
# ...

# %%
df_txt.drop(['index'],axis= 0, inplace= True)
df_txt.head()
# Out:
#               Q3                 Q4                       Q5          Q6  \
# index
# 0          India  Bachelor’s degree                    Other  5-10 years
# 1      Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2       Pakistan    Master’s degree        Software Engineer   1-3 years
# 3         Mexico    Doctoral degree       Research Scientist   20+ years
# 4          India    Doctoral degree                    Other   < 1 years
#
#            Q8                                                Q11  \
# index
# 0      Python                                           A laptop
# 1      Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2      Python                                           A laptop
# 3      Python  A cloud computing platform (AWS, Azure, GCP, h...
# 4      Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                       Q13                                    Q15  \
# index
# ...
